# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# data visiualization with countplot, boxplot, scatterplot
LABELS = ['Non-Fraud', 'Fraud']

# Count records per class (optional but useful for summary)
count_classes = df['Class'].value_counts()
print("Transaction count per class:")
print(count_classes)

# Seaborn bar plot
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Class', hue='Class', palette='Set2', legend=False)

# Set axis labels and title
plt.title("Transaction Class Distribution")
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.xticks(ticks=[0, 1], labels=LABELS)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Transaction count per class:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), sharey=True)
fig.suptitle('Transaction Amount Distribution by Class (Box Plot)', fontsize=14)

# Fraud transactions box plot
sns.boxplot(data=frauds, y='Amount', color='red', ax=ax1)
ax1.set_title('Fraud Transactions')
ax1.set_ylabel('Amount ($)')

# Normal transactions box plot
sns.boxplot(data=normal, y='Amount', color='green', ax=ax2)
ax2.set_title('Normal Transactions')
ax2.set_ylabel('')

# Final layout
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
sns.set_style('whitegrid')

# Set up subplots
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
f.suptitle('Time of Transaction vs Amount by Class', fontsize=14)

# Plot Fraud transactions
ax1.scatter(frauds['Time'], frauds['Amount'], color='red', alpha=0.6)
ax1.set_title('Fraud Transactions')
ax1.set_ylabel('Amount ($)')

# Plot Normal transactions
ax2.scatter(normal['Time'], normal['Amount'], color='green', alpha=0.6)
ax2.set_title('Normal Transactions')
ax2.set_xlabel('Time (in Seconds)')
ax2.set_ylabel('Amount ($)')

# Final layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# scale the amount by ss
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Amount'] = scaler.fit_transform(df[['Amount']])

# %%
# split the data
from sklearn.model_selection import train_test_split
x = df.drop('Class', axis=1)
y = df['Class']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Handle Class Imbalance for oversampling by smooth
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
x_train_res, y_train_res = sm.fit_resample(x_train, y_train)

print(f"Before SMOTE: {y_train.value_counts()}")
print(f"After SMOTE: {y_train_res.value_counts()}")
# Out:
# Before SMOTE: Class
# 0    199008
# 1       356
# Name: count, dtype: int64
# After SMOTE: Class
# 0    199008
# 1    199008
# Name: count, dtype: int64

# %%
# train the model with logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear', max_iter=1000)
model.fit(x_train_res, y_train_res)
y_pred_lr = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred_lr)
# Out:
# 0.9858034010978078

# %%
# train the model with random classifier
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x_train_res, y_train_res)
y_pred_rf = model.predict(x_test)

# %%
accuracy_score(y_test, y_pred_rf)
# Out:
# 0.9994967405170698

# %%
#evalute the model by classification ang confusion matrix 
from sklearn.metrics import classification_report, confusion_matrix
def evaluate_model(y_test, y_pred, model_name):
    print(f"--- {model_name} ---")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))

evaluate_model(y_test, y_pred_lr, "Logistic Regression")
evaluate_model(y_test, y_pred_rf, "Random Forest")
# Out:
# --- Logistic Regression ---
# [[84107  1200]
#  [   13   123]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     85307
#            1       0.09      0.90      0.17       136
#
#     accuracy                           0.99     85443
#    macro avg       0.55      0.95      0.58     85443
# weighted avg       1.00      0.99      0.99     85443
#
# --- Random Forest ---
# [[85282    25]
#  [   18   118]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.83      0.87      0.85       136
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.93      0.92     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# heatmap Plot Confusion Matrix
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d')
plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
